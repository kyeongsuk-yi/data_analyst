# %%
# !git clone https://github.com/AnalyticsKnight/yemoonsaBigdata/
# Out:
# Cloning into 'yemoonsaBigdata'...
# remote: Enumerating objects: 471, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 471 (delta 63), reused 43 (delta 43), pack-reused 363
# Receiving objects: 100% (471/471), 8.55 MiB | 12.19 MiB/s, done.
# Resolving deltas: 100% (248/248), done.

# %% [markdown]
# # 제 3회 기출복원문제

# %% [markdown]
# ## 2. 작업형 제 1 유형

# %% [markdown]
# ### 문제

# %% [markdown]
# 1) 다음은 California Housing 데이터 세트이다. 데이터 중 결측치가 있는 경우 해당 데이터의 행을 모두 제거하고, 첫 번째 행부터 순서대로 70% 까지의 데이터를 훈련 데이터로 추출한 데이터 세트를 구성한다. 변수 중 ‘housing_median_age’의 Q1(제1사분위수) 값을 정수로 계산하시오.
#
#
# - longitute: 경도
# - latitude: 위도
# - housing_median_age: 주택 나이의 중앙값
# - total_rooms: 전체 방 개수
# - total_bedrooms: 전체 침실 개수
# - population: 인구
# - households: 세대수
# - median_income: 소득의 중앙값
# - median_house_value: 주택가치
# - ocean_proximty: 바다근접도

# %% [markdown]
# ### 답

# %%
# 출력을 원할 경우 print() 함수 활용
# 예시) print(df.head())

# getcwd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가

# 데이터 파일 읽기 예제
import pandas as pd
housing = pd.read_csv('yemoonsaBigdata/datasets/Part3/301_housing.csv')

# 결측치 제거 dropna
housing_dropna = housing.dropna().reset_index(drop=True)
row_num = int(len(housing_dropna)*0.7)
# print(row_num)

train = housing_dropna.loc[:row_num-1]
# print(row_num, train.shape[0])
answer = int(train['housing_median_age'].quantile(0.25))
print(answer)

# 답안 제출 예시
# print(평균변수값)
# Out:
# 19

# %% [markdown]
# ### 문제

# %% [markdown]
# 2) 다음은 국가별 연도별 인구 10만명당 결핵 유병률 데이터 세트이다. 2000년도의 국가별 결핵 유병률 데이터 세트에서 2000년도의 평균값보다 더 큰 유병률 값을 가진 국가의 수를 계산하시오.
#
#
# - year: 연도
# - Afghanistan: 국가1 이름
# - Albania: 국가2 이름
# ...
# - Zambia: 국가192 이름
# - Zimbabwe: 국가193 이름

# %% [markdown]
# ### 답

# %%
# 출력을 원할 경우 print() 함수 활용
# 예시) print(df.head())

# getcwd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가

# 데이터 파일 읽기 예제
import pandas as pd
disease = pd.read_csv('yemoonsaBigdata/datasets/Part3/302_worlddata.csv')

# print(disease)
disease_s = disease[disease['year']==2000]
disease_st = disease_s.T
disease_st = disease_st.drop('year', axis=0).rename(columns={1:'value'})

mean_val = disease_st['value'].mean()
rst = disease_st[disease_st['value']>mean_val ]

answer = len(rst)
print(answer)

# 답안 제출 예시
# print(평균변수값)
# Out:
# 76

# %% [markdown]
# ### 문제

# %% [markdown]
# 3) 다음은 Titanic 데이터 세트이다. 주어진 데이터 세트의 컬럼 중 빈 값 또는 결측치를 확인하여, 결측치의 비율이 가장 높은 변수명을 출력하시오.
#
#
# - PassengerID: 승객 ID
# - Survived: 생존 여부
# - Pclass: 등급
# - Name: 승객 이름
# - Sex: 승객 성별
# - Age: 승객 나이
# - SibSp: 동승 자매/배우자 수
# - Parch: 동승 부모/자식 수
# - Ticket: 티켓 번호
# - Fare: 요금
# - Cabin: 선실 번호
# - Embarked: 탑승지

# %% [markdown]
# ### 답

# %%
# 출력을 원할 경우 print() 함수 활용
# 예시) print(df.head())

# getcwd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가

# 데이터 파일 읽기 예제
import pandas as pd
titanic = pd.read_csv('yemoonsaBigdata/datasets/Part3/303_titanic.csv')

tt_null = titanic.isnull().sum()
max_ind = tt_null.argmax()
answer = tt_null.index[max_ind]
# print(max_ind)
# print(tt_null)

print(answer)
# 답안 제출 예시
# print(평균변수값)
# Out:
# Age

# %% [markdown]
# ## 3. 작업형 제 2 유형

# %% [markdown]
# ### 문제

# %% [markdown]
# 1) 다음은 Travel Insurance 데이터 세트이다. 주어진 훈련 데이터 세트를 이용하여 고객별 여행보험 가입 여부 예측 모형을 만들고, 가장 높은 Accuracy 값을 가지는 최종 모델을 도출하시오. 해당 모델을 활용하여 보험 가입 여부 예측값을 계산하고 결과값은 csv 파일로 제출하시오.
# ※ 결과 제출 양식 : 제출한 예측값의 ROC_AUC 점수 결과를 통해 영역별 배점에 따라 최종 점수가 반영될 예정
#
#
# - ID: 고객 ID
# - Age: 고객 나이
# - Employment Type: 고객 직업 유형
# - GraduateOrNot: 대졸 여부
# - AnnualIncome: 연 소득
# - FamilyMembers: 가족 수
# - ChronicDiseases: 만성질환 여부
# - FrequentFlyer: FrequentFlyer 자격 여부
# - EverTravelledAbroad: 해외여행 경험
# - TravelInsurance: 여행보험 가입 여부 (0 : 미가입, 1 : 가입)

# %% [markdown]
# ### 답

# %%
# 출력을 원하실 경우 print() 함수 활용
# 예시) print(df.head())

# getcwd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가


# 패키지 불러오기 
import pandas as pd
import numpy as np 

from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split 

from sklearn.linear_model import LogisticRegression 
from sklearn.ensemble import RandomForestClassifier 
from xgboost import XGBClassifier 

from sklearn.metrics import roc_auc_score

# 1. 데이터 로딩 

X_test = pd.read_csv("yemoonsaBigdata/datasets/Part3/304_x_test.csv")
X_train = pd.read_csv("yemoonsaBigdata/datasets/Part3/304_x_train.csv")
y_train = pd.read_csv("yemoonsaBigdata/datasets/Part3/304_y_train.csv")

# print(X_train, '\n')
# print(X_test, '\n')
# print(y_train)

# 2. 데이터 전처리 

# print(X_train.isnull().sum(), '\n')
# print(X_test.isnull().sum(), '\n')
# print(y_train.isnull().sum())

# print(X_train.describe(), '\n')
# print(X_test.describe())

# print(X_train['ID'].nunique(), len(X_train))

del_cols = ['ID']
num_cols = ['Age',  'AnnualIncome',  'FamilyMembers',  'ChronicDiseases']
cat_cols = ['Employment Type', 'GraduateOrNot', 'FrequentFlyer', 'EverTravelledAbroad']
X_cols = num_cols + cat_cols
y_col = ['TravelInsurance']

# 데이터 인코딩
le = LabelEncoder()

X = pd.concat([X_train, X_test])

for _col in cat_cols:
  le.fit(X[_col])
  X_train[_col] = le.transform(X_train[_col])
  X_test[_col] = le.transform(X_test[_col])

# 3. 데이터 모형 구축
# 데이터 분할
X_tr, X_val, y_tr, y_val = train_test_split(X_train[X_cols], y_train[y_col], test_size=0.2, stratify=y_train[y_col], random_state=123)

# 데이터 스케일링 
sc = StandardScaler()
sc.fit(X_tr[num_cols])
X_tr[num_cols] = sc.transform(X_tr[num_cols])
X_val[num_cols] = sc.transform(X_val[num_cols])
X_test[num_cols] = sc.transform(X_test[num_cols])

def get_scores(model, X_tr, X_val, y_tr, y_val):

   y_tr_pred = model.predict_proba(X_tr)[:, 1]
   y_val_pred = model.predict_proba(X_val)[:, 1]
   auc_tr = roc_auc_score(y_tr, y_tr_pred)
   auc_val = roc_auc_score(y_val, y_val_pred)
   
   return f'train: {round(auc_tr, 4)}, valid: {round(auc_val, 4)}'

# lr = LogisticRegression()
# lr.fit(X_tr, y_tr)
# print('logistic: ', get_scores(lr, X_tr, X_val, y_tr, y_val))

# rf = RandomForestClassifier(random_state=123)
# rf.fit(X_tr, y_tr)
# print('rf: ', get_scores(rf, X_tr, X_val, y_tr, y_val))

# for d in range(5, 11):
#    rf = RandomForestClassifier(max_depth=d, min_samples_split=3, min_samples_leaf=2, random_state=123)
#    rf.fit(X_tr, y_tr)
#    print(f' - max_depth={d}:\t', get_scores(rf,  X_tr, X_val, y_tr, y_val))

xgb = XGBClassifier()
xgb.fit(X_train[X_cols], y_train[y_col])

y_pred = xgb.predict_proba(X_test[X_cols])[:, 1]

pd.DataFrame({'index': X_test.index, 'y_pred': y_pred}).to_csv('1234567.csv', index=False)
# print('Xgboost:\t', get_scores(xgb,  X_tr, X_val, y_tr, y_val))

# 답안 제출 참고
# 아래 코드 예측변수와 수험번호를 개인별로 변경하여 활용
# pd.DataFrame({'index': X_test.index, 'y_pred': pred}).to_csv('003000000.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
